# %%
import numpy as np

# %%
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([10, 20, 30, 40, 50, 60])

print("Input values:", X.ravel())
print("Target values:", y)
# Out:
# Input values: [1 2 3 4 5 6]
# Target values: [10 20 30 40 50 60]

# %%
new_value = 3.5
k = 2

# %%
distances = abs(X.ravel() - new_value)
nearest = np.argsort(distances)[:k]

print("Nearest input values:", X[nearest].ravel())
# Out:
# Nearest input values: [4 3]

# %%
prediction = np.mean(y[nearest])

print("Prediction:", prediction)
# Out:
# Prediction: 35.0
