# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
data = {
    'Attendance':[95,80,75,60,90,85,55,70,np.nan,88],
    'Study_Hours':[6,5,4,2,7,6,1,3,5,np.nan],
    'Internal_Marks':[28,24,22,12,30,26,10,18,25,27],
    'Result':['Pass','Pass','Pass','Fail','Pass','Pass','Fail','Fail','Pass','Pass']
}
df  =pd.DataFrame(data)
print('Raw Dataset')
print(df.head())
# Out:
# Raw Dataset
#    Attendance  Study_Hours  Internal_Marks Result
# 0        95.0          6.0              28   Pass
# 1        80.0          5.0              24   Pass
# 2        75.0          4.0              22   Pass
# 3        60.0          2.0              12   Fail
# 4        90.0          7.0              30   Pass

# %%
sample_data = df.sample(n=8, random_state=1)
print('Sample Dataset')
print(sample_data)
# Out:
# Sample Dataset
#    Attendance  Study_Hours  Internal_Marks Result
# 2        75.0          4.0              22   Pass
# 9        88.0          NaN              27   Pass
# 6        55.0          1.0              10   Fail
# 4        90.0          7.0              30   Pass
# 0        95.0          6.0              28   Pass
# 3        60.0          2.0              12   Fail
# 1        80.0          5.0              24   Pass
# 7        70.0          3.0              18   Fail

# %%
print(sample_data.isnull())
# Out:
#    Attendance  Study_Hours  Internal_Marks  Result
# 2       False        False           False   False
# 9       False         True           False   False
# 6       False        False           False   False
# 4       False        False           False   False
# 0       False        False           False   False
# 3       False        False           False   False
# 1       False        False           False   False
# 7       False        False           False   False
